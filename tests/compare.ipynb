# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
mypath = '/Users/yaronetokayer/YaleDrive/Research/SIDM/pygtfcode/tests/Model000/logfile.txt'
fortpath = '/Users/yaronetokayer/YaleDrive/Research/SIDM/gtfcode_results/Model001/logfile'

# %%
myrows = np.loadtxt(mypath, skiprows=1)
fortrows = np.loadtxt(fortpath, skiprows=40, max_rows=2020)

# %%
myt = myrows[:,1]
myrho = myrows[:,3]
fortt = fortrows[:,1]
fortrho = fortrows[:,3]

# %%
fig, ax = plt.subplots(1, 1, figsize=(7, 6))

ax.plot(fortt, fortrho, label='fortran')
ax.plot(myt, myrho, ls='--', label='Python')
ax.set_yscale('log')
ax.set_ylabel('t')
ax.set_ylabel('rho')
ax.legend()
ax.grid(True, which="both", ls="--")
